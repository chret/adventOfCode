# %%
import numpy as np

opcodeInput=np.loadtxt("input_day23.txt",delimiter=",",dtype=np.int64)

class OpCodeManager:
    def __init__(self, opcode):
        self.opcode = opcode
        self.relativeBaseIdx=0
    def __getitem__(self, idx):
        if idx >= self.opcode.size:
            self.opcode.resize(idx+1, refcheck=False) # fill rest with zeros
        return self.opcode[idx]
    def __setitem__(self, idx, value):
        if idx >= self.opcode.size:
            self.opcode.resize(idx+1, refcheck=False) # fill rest with zeros
        self.opcode[idx] = value

def decodeCommand(command):
    code=command%100
    p1Mode=int(command/100)%10
    p2Mode=int(command/1000)%10
    p3Mode=int(command/10000)%10
    return [code, p1Mode, p2Mode, p3Mode]

def getArgument(opcode, mode, parameter):
    if mode == 0:
        # position mode
        return opcode[parameter]
    elif mode == 1:
        # immediate mode
        return parameter
    else:
        # relative mode
        return opcode[opcode.relativeBaseIdx+parameter]
    
def getWritePosition(opcode, mode, parameter):
    if mode == 0:
        # position mode
        return parameter
    elif mode == 1:
        # immediate mode
        print("ERROR! Immediate mode not intended for writing")
        print(mode, parameter, opcode)
    else:
        # relative mode
        return opcode.relativeBaseIdx+parameter

# %%
import threading, queue

class Computer(threading.Thread):
    def __init__(self, opcodeMgr, queues, address,inputQueue,nat):
        super(Computer, self).__init__()
        self.opcode = opcodeMgr
        self.queues = queues
        self.address = address
        self.outputQueue=[]
        self.inputQueue=inputQueue
        self.nat=nat
        
    def sendOutput(self):
        recvAddr=self.outputQueue[0]
        X=self.outputQueue[1]
        Y=self.outputQueue[2]
        if recvAddr== 255:
            print("Addr ", self.address, " sending to NAT of packet ",( X, Y))
            self.nat.insert(0,(X,Y))
        else:
            self.queues[recvAddr].put_nowait((X,Y))
        self.outputQueue=[]
        
    def join(self, timeout=None):
        super(Computer, self).join(timeout)
        
    def isIdle(self):
        if self.queues[self.address].empty() and len(self.inputQueue) == 0 and len(self.outputQueue) == 0:
            return True
        return False
    
    def run(self):
        idx=0
    
        while True:

            decoded = decodeCommand(self.opcode[idx])
            if decoded[0] == 99:
                print("Finished!")
                return 0
            elif decoded[0] == 1:
                #add p1 p2 p3
                p1 = self.opcode[idx+1]
                p2 = self.opcode[idx+2]
                p3 = self.opcode[idx+3]
                arg1 = getArgument(self.opcode,decoded[1],p1)
                arg2 = getArgument(self.opcode,decoded[2],p2)
                arg3 = getWritePosition(self.opcode,decoded[3],p3)
                self.opcode[arg3] = arg1 + arg2
                idx+=4
            elif decoded[0] == 2:
                #multiply p1 p2 p3
                p1 = self.opcode[idx+1]
                p2 = self.opcode[idx+2]
                p3 = self.opcode[idx+3]
                arg1 = getArgument(self.opcode,decoded[1],p1)
                arg2 = getArgument(self.opcode,decoded[2],p2)
                arg3 = getWritePosition(self.opcode,decoded[3],p3)
                self.opcode[arg3] = arg1 * arg2
                idx+=4
            elif decoded[0] == 3:
                #input p1
                p1 = self.opcode[idx+1]
                arg1 = getWritePosition(self.opcode,decoded[1],p1)
                var=-1
                if len(self.inputQueue) > 0:
                    var = self.inputQueue.pop(0)
                else:
                    try:
                        inputPair = self.queues[self.address].get(False) # non-blocking wait, will throw exception if empty
                        var=inputPair[0]
                        self.inputQueue.append(inputPair[1])
                    except queue.Empty:
                        var=-1 # queue was empty
                #if var != -1:
                #    print("Input on addr ", self.address, ": ", var)
                self.opcode[arg1] = np.int64(var)
                idx+=2
            elif decoded[0] == 4:
                #output p1
                p1 = self.opcode[idx+1]
                arg1 = getArgument(self.opcode,decoded[1],p1)
                self.outputQueue.append(arg1)
                #print("Output on addr ", self.address, ": ", arg1)
                if len(self.outputQueue) == 3:
                    self.sendOutput()
                idx+=2
            elif decoded[0] == 5:
                #jump-if-true p1 p2
                p1 = self.opcode[idx+1]
                p2 = self.opcode[idx+2]
                arg1 = getArgument(self.opcode,decoded[1],p1)
                arg2 = getArgument(self.opcode,decoded[2],p2)
                if arg1 != 0:
                    idx=arg2
                else:      
                    idx=idx+3
            elif decoded[0] == 6:
                #jump-if-false p1 p2
                p1 = self.opcode[idx+1]
                p2 = self.opcode[idx+2]
                arg1 = getArgument(self.opcode,decoded[1],p1)
                arg2 = getArgument(self.opcode,decoded[2],p2)
                if arg1 == 0:
                    idx=arg2
                else:      
                    idx+=3
            elif decoded[0] == 7:
                #less-than p1 p2 p3
                p1 = self.opcode[idx+1]
                p2 = self.opcode[idx+2]
                p3 = self.opcode[idx+3]
                arg1 = getArgument(self.opcode,decoded[1],p1)
                arg2 = getArgument(self.opcode,decoded[2],p2)
                arg3 = getWritePosition(self.opcode,decoded[3],p3)
                if arg1 < arg2:
                    self.opcode[arg3]=1
                else:      
                    self.opcode[arg3]=0
                idx+=4
            elif decoded[0] == 8:
                #equals p1 p2 p3
                p1 = self.opcode[idx+1]
                p2 = self.opcode[idx+2]
                p3 = self.opcode[idx+3]
                arg1 = getArgument(self.opcode,decoded[1],p1)
                arg2 = getArgument(self.opcode,decoded[2],p2)
                arg3 = getWritePosition(self.opcode,decoded[3],p3)
                if arg1 == arg2:
                    self.opcode[arg3]=1
                else:      
                    self.opcode[arg3]=0
                idx+=4
            elif decoded[0] == 9:
                # change relative base p1
                p1 = self.opcode[idx+1]
                arg1 = getArgument(self.opcode,decoded[1],p1)
                self.opcode.relativeBaseIdx += arg1
                idx+=2
            else:
                print("Invalid code ", self.opcode, idx, self.opcode[idx], decoded)
                return

# %%
# task 1
numAddresses=50
queues = [queue.Queue() for i in range(0,numAddresses)]

# Create the "thread pool"
pool = [Computer(opcodeMgr=OpCodeManager(opcodeInput.copy()), queues=queues,address=i,inputQueue=[i]) for i in range(0,numAddresses)]

# Start all threads
for thread in pool:
    thread.start()

# Ask threads to die and wait for them to do it
for thread in pool:
    thread.join()
# Out:
# Input on addr  0 :  0
# Output on addr  0 :  24
# Output on addr  0 :  100153
# Output on addr  0 :  18508
# Output on addr  0 :  42
# Input on addr  1 :  1Output on addr  0 :  41179
# Output on addr  0 :  18508
# Output on addr  0 :  42
# Output on addr  0 :  123537
# Output on addr  0 :  18508
# Output on addr  0 :  48
# Output on addr  0 :  24151
# Output on addr  0 :  18508
# Output on addr  0 :  Input on addr  2
#  :  2
# Input on addr  3 :  3
# 48
# Output on addr  0 :  48302
# Output on addr  0 :  18508
# Output on addr  0 :  48
# Output on addr  0 :  72453
# Input on addr  4 :  4
# Output on addr  0 :  18508
# Input on addr  5 :  5
# Input on addr  6 :  6
# Input on addr  7 :  7
# Input on addr  8 :  8
# Input on addr  9 :  9
# Input on addr  10 :  10
# Output on addr  10 :  27
# Output on addr  10 :  188966
# Output on addr  10 :  -62
# Output on addr  9 :  1
# Output on addr  9 :  68314
# Output on addr  9 :  125
# Input on addr  11 :  11
# Output on addr  11Input on addr  1 :  Input on addr  12 :  12
# Output on addr  12  :  68314
# Input on addr  1 :  1:  38
# Output on addr  12 : 125
# Output on addr  11
# Input on addr  13 :  13
# Output on addr  13 :  149444
# Output on addr  12 :  1041
#   :  136628
# Output on addr  11 :  10
# Output on addr  11 :  35
# Output on addr  11 :  488778
# Output on addr  11 :  10
# 8
# Output on addr  13 :  45718
# Output on addr  13 :  49395
# Input on addr  1 :  136628
# Input on addr  1 :  10
# Input on addr  14 :  14
# Input on addr  8 :  45718
# Input on addr  8 :  49395Input on addr  15
# Input on addr  16 :  16
#  :  Input on addr  17 :  17
# Output on addr  17Input on addr  18 : 15
# Output on addr  15 :   18
#  :  3
# Output on addr  17 :  227649
# Output on addr  17 :  1381
# Output on addr  17 :  25
# Output on addr  17 :  115306
# Input on addr  3 :  Output on addr  17227649 :  1381
# Input on addr  19 :  19
# Output on addr  19 :  38
# 16
# Output on addr  15Output on addr  19
# :  37361
# Output on addr  19 :  3
# Output on addr  19 : Input on addr  3 :  1381
#  38
# Output on addr  19  Input on addr  20 :  20
# Output on addr  20 :  8
# Output on addr  20 :  167667
# Output on addr  15 : :  11
#  Input on addr  16 :  : 167667 22859
# Output on addr
# Input on addr  16 :  1174722
# Output on addr  1920 :
#  162381
#  :  3
# Input on addr  8 :  22859
# Input on addr  8 :  162381
# Input on addr  21Input on addr  22 :   :  21
# Output on addr  21 :  25
# Output on addr 22
#  21 Input on addr  23 :  23
# Output on addr  23 :  32
# Output on addr  23 :  :  5765356659
# Output on addr
# Output on addr Input on addr  24 :  24
# Input on addr  24 :  100153
# Input on addr  24 :  18508
#  23 Input on addr  25 :  25
# : Input on addr  21 :  -24
#  Input on addr  26 :  262
#  25 :  115306
# Input on addr  25 :  1381
# Input on addr  25 :  Output on addr  26 :  8
# Output on addr  26 :  68577
# Output on addr  26 :  -28447
# Input on addr
# 57653
# Input on addr  Input on addr  27 :  Input on addr  28 :  28 8 25 :  -24
# Output on addr Input on addr  29 :  29
# Output on addr  29 :  38
# Output on addr  29 : :  68577
# Input on addr  8 :
#   Input on addr  30 27
# Input on addr  27 :  188966
# Input on addr  27 -28447:  -62
# 23
# :  30
# Output on addr  30 :  1
# Input on addr  31 :   112083
# Output on addr  29 :  149
# Output on addr  8 :   46
# Output on addr  8 :  49177
# Output on addr  8 :  183329
# 31
# Output on addr  30 :  34157
# Output on addr  30 : Input on addr  32 :   5
# Output on addr  30 :  1
# 32Output on addr  30 :  102471
# Output on addr  30 :  5
# Output on addr  30 :  35
# Input on addr :  28
# Output on addr  23 : Output on addr  1 :  34157
#   3574
# Output on addr  23 :  Input on addr 2
# Output on addr  23 :  44
# Output on addr  23 :  191974
# Output on addr  23 : 30 :  325852
# Output on addr  30 :  5
#  1 :  5
# Input on addr  1 :  102471
# Input on addr  1 : Input on addr  33 :  33
# Output on addr  33 :  35
# Input on addr  28 :  3574
# Input on addr  28 :
# Output on addr  33 :   Input on addr  32 2
# 5
# Output on addr  1 :  35
# Output on addr  1 :  2
# Output on addr  23 :  3
# Output on addr  23  407315
# Output on addr  1 :  31250
# :  75883
# Output on addr  23 :  2
# Output on addr  23 :  162926
# Output on addr  33 :  160
# Input on addr  34 :  Input on addr  334
# Output on addr  34 :  27
# Output on addr  34 :  283449
# Output on addr  34 :  1
# Output on addr  34 :  25
# Output on addr  34 :  172959
# Output on addr  34 :  :  56659
# Input on addr  32 :  Input on addr  35 Input on addr :  35
# 1
#  :  75883
# Input on addr  3 :  2
# 2
# Input on addr  36 :  36
# 46
# Output on addr  23 :  98354
# Output on addr  23 27 :  283449
# Input on addr  27 :  :  2
# Output on addr  23 : Input on addr  35 :  488778
# Input on addr  35 :  10
# Input on addr  35 :  325852
# Input on addr  35 :  5
# Input on addr  25 :  172959
# Input on addr  25  16
# Output on addr  23 :  111778
# Output on addr  23 :  2
# Output on addr  23 :  35
# Output on addr  23 :  81463 :
# Input on addr  16Input on addr Output on addr   1
#   23 :  2
# Output on addr  23 :  35
# Output on addr  23 :  244389
# Output on addr  23 :  2
# Output on addr 1
# 35 :  407315
# Input on addr  35 :  31250
# Input on addr  35 :  162926
# Input on addr  35 Input on addr  37 :  37
# Output on addr  37 :  45
# Output on addr  37 : :   Input on addr  38 :  38
# Input on addr  38 :  149444
#  25 :  42
# Output on addr  25 :  82358Input on addr Input on addr  38 :  1041160
# Input on addr  35 :  81463
# Input on addr  35 :  2
# Input on addr  35 :  244389
# :
# Output on addr  25 Input on addr  35 :
# Input on addr  38 :  39 :  -33144
# 37361
# Input on addr   :  39
# Output on addr  39 :  45
# Output on addr  39 :  3083
# Output on addr  39 : Input on addr  40 11177838 Input on addr :  40
#  2
# Output on addr  35 : 2780339
#   41 :  41Input on addr  42 :  42
# Input on addr  42 :  41179
# Input on addr  42 :  18508
# Input on addr  42 :  123537
# Input on addr  42 :  18508
# :  3
#  6166
# Output on addr  37Input on addr  38 :  74722
# Input on addr  38 :  3
# Input on addr  38 :  112083
# Input on addr  38 :
# Input on addr  16 :  2
# Input on addr  42 :  82358
# Input on addr  42 :  -33144
# Output on addr  42 :  18
#
#  :  32
# Input on addr  43 :  43
# Output on addr  42 : Output on addr  37 :   43  147384149
#
# Input on addr  44 :  Output on addr  35 :  120514
# 44Output on addr  35 :  Output on addr  38 :  71000000000
# Input on addr  43 :
# Output on addr  42 120514Input on addr  45 :  45
#
# Output on addr
# Input on addr  43 :  Output on addr  38 :  160526
# Output on addr  38 :  1395981
#
# Input on addr  45 :  3083
# Input on addr  45 :  2780339
# Input on addr  45
# Input on addr  44Input on addr  46 :  46
# Input on addr  46 :  49177
# Input on addr  46 :  183329
# Input on addr  :  191974
# Input on addr  44 :  2
#  46Input on addr 37   1000000000 :  98354
# Input on addr :   46-11353346745216
# Input on addr  47 :  47
#  7 :  160526Input on addr  48 : :
# Input on addr  18 6166
# Input on addr  45 :  32
# Output on addr  45 :  32
# Output on addr  45 :  113318
# Output on addr  45 :  :  50551
# Output on addr  37 : :  32
# Input on addr  49 Input on addr  4
# 88970848
# Input on addr  Input on addr  7 :  1395981
#  :  50551
# Input on addr  4 :   48
# Input on addr  48 :  24151
# Input on addr  48 : :  2
# Output on addr  46  :  :  49
# Output on addr  49 :  27
# Output on addr  49 :  94483
# Output on addr  49 :  4003
# 18508 14738
# Input on addr  18 7
# Output on addr  46 :   : 32Input on addr  27 : 32 -11353346745216
#  94483
# Input on addr  27 :  4003
# Output on addr  27 :  7
# Output on addr  27
# 80263Input on addr  48 :
#
# Output on addr  46 :  366658
#  :  240789:  113318
# Input on addr  32 : Input on addr  7 :  80263
# 48302
# Input on addr  48 :  18508
# Input on addr  48Input on addr  7 :  72453
# Input on addr  48 :  18508
#
# Output on addr  48 :  :  366658
#  18
# Output on addr  48 :  29476
# Output on addr  48 :  Output on addr  27 :  -248186
#  Input on addr  7 :  240789
# Input on addr  7 :  -248186
# Output on addr  7 :  4
# Output on addr  7 :  101102
# Output on addr  7 :  1514453
# 88970848
# Output on addr  32 :  28
# 6339842552512Output on addr  32 :  1787
# Output on addr  32 :  177941696
# Input on addr  4 :  101102
#
# Input on addr  28 :  1787
# Input on addr  28 Input on addr  Input on addr  18 :  29476
# Input on addr  18 :  6339842552512
# : 4  :  1514453
# Output on addr  4 :  16
# 177941696Output on addr
# Output on addr  28 :  44
#  4 :  55889
# Output on addr  4 :  48462496
# Output on addr  28 :  95987
# Output on addr  28 :  355883392
# Input on addr  16 :  55889
# Input on addr  16 :  48462496
# Output on addr  16 :  24
# Output on addr  Input on addr  44 :  16 :  200306
# Output on addr  16 :  1066174912
# 95987
# Input on addr  44Input on addr  24 :   :  355883392
# Output on addr  44 :  3
# 200306
# Input on addr  24 :  1066174912
# Output on addr  24 :  18
# Output on addr  44 :  151766
# Output on addr  44Output on addr  24 :  711766784
# Input on addr  3 :  151766
# Input on addr  3 :  711766784
# Output on addr  3 :  18
# Output on addr  3 :  7369
#  :  22107
# Output on addr  24 :  19732765271296
# Output on addr  3 : Input on addr  18 :  22107
# Input on addr  18 1965899857408
#  :  19732765271296
# Input on addr  18 :  7369
# Input on addr  18 :  1965899857408
# Output on addr  18 :  43
# Output on addr  18 :  60257
# Output on addr  18 :  16685160936000
# Input on addr  43 :  60257
# Input on addr  43 :  16685160936000
# Output on addr  43 :  255
# Output on addr  43 :  26161
# Output on addr  43 :  16685
# Sending to address  255  requested of packet  (26161, 16685)

# %%
# task 2
numAddresses=50
queues = [queue.Queue() for i in range(0,numAddresses)]

natMemory=[]

# Create the "thread pool"
pool = [Computer(opcodeMgr=OpCodeManager(opcodeInput.copy()), queues=queues,address=i,inputQueue=[i],nat=natMemory) for i in range(0,numAddresses)]

# Start all threads
for thread in pool:
    thread.start()

formerY=-1
while True:
    # check if IDLE
    idle=True
    for thread in pool:
        idle = idle and thread.isIdle()
    if idle and len(natMemory) > 0:
        print("NAT: sending ", natMemory[0], " to 0")
        if formerY==natMemory[0][1]:
            print("SOLUTION: ", formerY)
        formerY=natMemory[0][1]
        queues[0].put_nowait(natMemory[0])
    
# Ask threads to die and wait for them to do it
for thread in pool:
    thread.join()
# Out:
# Addr  43  sending to NAT of packet  (26161, 16685)
# NAT: sending  (26161, 16685)  to 0
# Addr  43  sending to NAT of packet  (26161, 17803)
# Addr  43  sending to NAT of packet  (26161, 18811)
# Addr  43  sending to NAT of packet  (26161, 18187)
# Addr  43  sending to NAT of packet  (26161, 17624)
# Addr  43  sending to NAT of packet  (26161, 17116)
# Addr  43  sending to NAT of packet  (26161, 15173)
# NAT: sending  (26161, 15173)  to 0
# Addr  43  sending to NAT of packet  (26161, 13560)
# Addr  43  sending to NAT of packet  (26161, 13140)
# Addr  43  sending to NAT of packet  (26161, 12757)
# Addr  43  sending to NAT of packet  (26161, 12409)
# Addr  43  sending to NAT of packet  (26161, 13245)
# Addr  43  sending to NAT of packet  (26161, 14005)
# NAT: sending  (26161, 14005)  to 0
# Addr  43  sending to NAT of packet  (26161, 13736)
# Addr  43  sending to NAT of packet  (26161, 13488)
# Addr  43  sending to NAT of packet  (26161, 13259)
# Addr  43  sending to NAT of packet  (26161, 12014)
# Addr  43  sending to NAT of packet  (26161, 12601)
# Addr  43  sending to NAT of packet  (26161, 13143)
# NAT: sending  (26161, 13143)  to 0
# Addr  43  sending to NAT of packet  (26161, 13543)
# Addr  43  sending to NAT of packet  (26161, 13919)
# Addr  43  sending to NAT of packet  (26161, 13750)
# Addr  43  sending to NAT of packet  (26161, 13591)
# Addr  43  sending to NAT of packet  (26161, 13442)
# Addr  43  sending to NAT of packet  (26161, 12523)
# NAT: sending  (26161, 12523)  to 0
# Addr  43  sending to NAT of packet  (26161, 12793)
# Addr  43  sending to NAT of packet  (26161, 13051)
# Addr  43  sending to NAT of packet  (26161, 12390)
# Addr  43  sending to NAT of packet  (26161, 12282)
# Addr  43  sending to NAT of packet  (26161, 12180)
# Addr  43  sending to NAT of packet  (26161, 12083)
# NAT: sending  (26161, 12083)  to 0
# Addr  43  sending to NAT of packet  (26161, 11614)
# Addr  43  sending to NAT of packet  (26161, 11797)
# Addr  43  sending to NAT of packet  (26161, 11973)
# Addr  43  sending to NAT of packet  (26161, 11904)
# Addr  43  sending to NAT of packet  (26161, 11837)
# Addr  43  sending to NAT of packet  (26161, 11773)
# NAT: sending  (26161, 11773)  to 0
# Addr  43  sending to NAT of packet  (26161, 11728)
# Addr  43  sending to NAT of packet  (26161, 11684)
# Addr  43  sending to NAT of packet  (26161, 11641)
# Addr  43  sending to NAT of packet  (26161, 11765)
# Addr  43  sending to NAT of packet  (26161, 11886)
# Addr  43  sending to NAT of packet  (26161, 11555)
# NAT: sending  (26161, 11555)  to 0
# Addr  43  sending to NAT of packet  (26161, 11640)
# Addr  43  sending to NAT of packet  (26161, 11724)
# Addr  43  sending to NAT of packet  (26161, 11694)
# Addr  43  sending to NAT of packet  (26161, 11461)
# Addr  43  sending to NAT of packet  (26161, 11432)
# Addr  43  sending to NAT of packet  (26161, 11403)
# NAT: sending  (26161, 11403)  to 0
# Addr  43  sending to NAT of packet  (26161, 11382)
# Addr  43  sending to NAT of packet  (26161, 11362)
# Addr  43  sending to NAT of packet  (26161, 11342)
# Addr  43  sending to NAT of packet  (26161, 11401)
# Addr  43  sending to NAT of packet  (26161, 11458)
# Addr  43  sending to NAT of packet  (26161, 11296)
# NAT: sending  (26161, 11296)  to 0
# Addr  43  sending to NAT of packet  (26161, 11282)
# Addr  43  sending to NAT of packet  (26161, 11268)
# Addr  43  sending to NAT of packet  (26161, 11255)
# Addr  43  sending to NAT of packet  (26161, 11141)
# NAT: sending  (26161, 11141)  to 0
# Addr  43  sending to NAT of packet  (26161, 11181)
# Addr  43  sending to NAT of packet  (26161, 11221)
# Addr  43  sending to NAT of packet  (26161, 11201)
# Addr  43  sending to NAT of packet  (26161, 11182)
# Addr  43  sending to NAT of packet  (26161, 11163)
# Addr  43  sending to NAT of packet  (26161, 11221)
# Addr  43  sending to NAT of packet  (26161, 11278)
# Addr  43  sending to NAT of packet  (26161, 11113)
# NAT: sending  (26161, 11113)  to 0
# Addr  43  sending to NAT of packet  (26161, 11083)
# Addr  43  sending to NAT of packet  (26161, 11093)
# Addr  43  sending to NAT of packet  (26161, 11103)
# NAT: sending  (26161, 11103)  to 0
# Addr  43  sending to NAT of packet  (26161, 11100)
# Addr  43  sending to NAT of packet  (26161, 11096)
# Addr  43  sending to NAT of packet  (26161, 11093)
# Addr  43  sending to NAT of packet  (26161, 11082)
# Addr  43  sending to NAT of packet  (26161, 11086)
# Addr  43  sending to NAT of packet  (26161, 11090)
# Addr  43  sending to NAT of packet  (26161, 11088)
# Addr  43  sending to NAT of packet  (26161, 11087)
# Addr  43  sending to NAT of packet  (26161, 11086)
# NAT: sending  (26161, 11086)  to 0
# Addr  43  sending to NAT of packet  (26161, 11068)
# Addr  43  sending to NAT of packet  (26161, 11066)
# Addr  43  sending to NAT of packet  (26161, 11064)
# Addr  43  sending to NAT of packet  (26161, 11062)
# Addr  43  sending to NAT of packet  (26161, 11068)
# Addr  43  sending to NAT of packet  (26161, 11074)
# NAT: sending  (26161, 11074)  to 0
# Addr  43  sending to NAT of packet  (26161, 11073)
# Addr  43  sending to NAT of packet  (26161, 11077)
# Addr  43  sending to NAT of packet  (26161, 11076)
# Addr  43  sending to NAT of packet  (26161, 11063)
# Addr  43  sending to NAT of packet  (26161, 11067)
# Addr  43  sending to NAT of packet  (26161, 11066)
# NAT: sending  (26161, 11066)  to 0
# Addr  43  sending to NAT of packet  (26161, 11065)
# Addr  43  sending to NAT of packet  (26161, 11064)
# Addr  43  sending to NAT of packet  (26161, 11063)
# Addr  43  sending to NAT of packet  (26161, 11054)
# Addr  43  sending to NAT of packet  (26161, 11057)
# Addr  43  sending to NAT of packet  (26161, 11060)
# NAT: sending  (26161, 11060)  to 0
# Addr  43  sending to NAT of packet  (26161, 11059)
# Addr  43  sending to NAT of packet  (26161, 11059)
# Addr  43  sending to NAT of packet  (26161, 11058)
# Addr  43  sending to NAT of packet  (26161, 11060)
# Addr  43  sending to NAT of packet  (26161, 11062)
# Addr  43  sending to NAT of packet  (26161, 11056)
# NAT: sending  (26161, 11056)  to 0
# Addr  43  sending to NAT of packet  (26161, 11052)
# Addr  43  sending to NAT of packet  (26161, 11051)
# Addr  43  sending to NAT of packet  (26161, 11051)
# Addr  43  sending to NAT of packet  (26161, 11050)
# Addr  43  sending to NAT of packet  (26161, 11052)
# Addr  43  sending to NAT of packet  (26161, 11053)
# NAT: sending  (26161, 11053)  to 0
# Addr  43  sending to NAT of packet  (26161, 11050)
# Addr  43  sending to NAT of packet  (26161, 11050)
# Addr  43  sending to NAT of packet  (26161, 11049)
# Addr  43  sending to NAT of packet  (26161, 11049)
# Addr  43  sending to NAT of packet  (26161, 11050)
# Addr  43  sending to NAT of packet  (26161, 11051)
# NAT: sending  (26161, 11051)  to 0
# Addr  43  sending to NAT of packet  (26161, 11052)
# Addr  43  sending to NAT of packet  (26161, 11052)
# Addr  43  sending to NAT of packet  (26161, 11052)
# Addr  43  sending to NAT of packet  (26161, 11052)
# Addr  43  sending to NAT of packet  (26161, 11052)
# Addr  43  sending to NAT of packet  (26161, 11050)
# NAT: sending  (26161, 11050)  to 0
# Addr  43  sending to NAT of packet  (26161, 11049)
# Addr  43  sending to NAT of packet  (26161, 11049)
# Addr  43  sending to NAT of packet  (26161, 11049)
# Addr  43  sending to NAT of packet  (26161, 11050)
# Addr  43  sending to NAT of packet  (26161, 11050)
# Addr  43  sending to NAT of packet  (26161, 11049)
# NAT: sending  (26161, 11049)  to 0
# Addr  43  sending to NAT of packet  (26161, 11049)
# Addr  43  sending to NAT of packet  (26161, 11050)
# Addr  43  sending to NAT of packet  (26161, 11050)
# Addr  43  sending to NAT of packet  (26161, 11049)
# Addr  43  sending to NAT of packet  (26161, 11049)
# Addr  43  sending to NAT of packet  (26161, 11048)
# NAT: sending  (26161, 11048)  to 0
# Addr  43  sending to NAT of packet  (26161, 11049)
# Addr  43  sending to NAT of packet  (26161, 11049)
# Addr  43  sending to NAT of packet  (26161, 11049)
# Addr  43  sending to NAT of packet  (26161, 11049)
# Addr  43  sending to NAT of packet  (26161, 11049)
# Addr  43  sending to NAT of packet  (26161, 11048)
# NAT: sending  (26161, 11048)  to 0
# SOLUTION:  11048
# NAT: sending  (26161, 11048)  to 0
# SOLUTION:  11048
# NAT: sending  (26161, 11048)  to 0
# SOLUTION:  11048
